# %%
import io
import json
import os
from pathlib import Path

import boto3
import pandas as pd
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", 100)

from tqdm.notebook import tqdm

# %%
S3_ACCESS_KEY_ID = ""
S3_SECRET_ACCESS_KEY = ""

DATA_PATH = Path("/usr/src/app/data/")

# %%
s3 = boto3.resource(
    "s3",
    aws_access_key_id=S3_ACCESS_KEY_ID,
    aws_secret_access_key=S3_SECRET_ACCESS_KEY
)


def read_json_from_s3(bucket_name: str, key: str) -> pd.DataFrame:
    return json.loads(
        s3.Object(bucket_name=bucket_name, key=key)
        .get()["Body"]
        .read()
        .decode("utf-8")
    )


def read_parquet_from_s3(bucket_name: str, key: str) -> pd.DataFrame:
    return pd.read_parquet(
        io.BytesIO(
            s3.Object(bucket_name=bucket_name, key=key)
            .get()["Body"]
            .read()
        )
    )

def get_df_players(raw_game: dict) -> pd.DataFrame:
    return pd.DataFrame(
        [
            {
                "player_id": player.get("playerId"),
                "team_id": player.get("teamId"),
                "season": raw_game.get("season"),
                "first_name": player.get("firstName").get("default"),
                "last_name": player.get("lastName").get("default"),
                "sweater_number": player.get("sweaterNumber"),
                "position_code": player.get("positionCode"),
                "headshot": player.get("headshot"),
            } 
            for player in raw_game.get("rosterSpots")
        ]
    )

# %%
BUCKET_NAME = "frozen-facts-center-raw"
KEY = "games/2020/regular/2020020001.json"

raw_game = read_json_from_s3(bucket_name=BUCKET_NAME, key=KEY)
df_players = get_df_players(raw_game=raw_game)

df_players
# Out:
#     player_id  team_id    season first_name     last_name  sweater_number  \
# 0     8470880        4  20202021      Brian       Elliott              37
# 1     8471215        5  20202021     Evgeni        Malkin              71
# 2     8471675        5  20202021     Sidney        Crosby              87
# 3     8471724        5  20202021       Kris        Letang              58
# 4     8473512        4  20202021     Claude        Giroux              28
# 5     8474027        4  20202021     Justin         Braun              61
# 6     8474037        4  20202021      James  van Riemsdyk              25
# 7     8474098        5  20202021     Colton      Sceviour               7
# 8     8474161        4  20202021      Jakub       Voracek              93
# 9     8475208        5  20202021      Brian      Dumoulin               8
# 10    8475722        5  20202021      Jason        Zucker              16
# 11    8475763        4  20202021      Kevin         Hayes              13
# 12    8475810        5  20202021      Bryan          Rust              17
# 13    8476461        4  20202021       Sean     Couturier              14
# 14    8476872        4  20202021      Scott      Laughton              21
# 15    8476873        5  20202021       Mark     Jankowski              14
# 16    8476875        5  20202021       Mike      Matheson               5
# 17    8476879        5  20202021       Cody          Ceci               4
# 18    8476927        5  20202021      Teddy       Blueger              53
# 19    8476979        4  20202021       Erik    Gustafsson              56
# 20    8477290        4  20202021    Michael         Raffl              12
# 21    8477404        5  20202021       Jake      Guentzel              59
# 22    8477462        4  20202021     Robert          Hagg               8
# 23    8477465        5  20202021    Tristan         Jarry              35
# 24    8477948        4  20202021     Travis       Sanheim               6
# 25    8477955        5  20202021      Jared        McCann              19
# 26    8477969        5  20202021     Marcus    Pettersson              28
# 27    8477979        4  20202021    Nicolas    Aube-Kubel              62
# 28    8478043        5  20202021        Sam      Lafferty              18
# 29    8478067        4  20202021      Oskar      Lindblom              23
# 30    8478439        4  20202021     Travis       Konecny              11
# 31    8478500        4  20202021       Ivan      Provorov               9
# 32    8478507        5  20202021       John        Marino               6
# 33    8478542        5  20202021       Evan     Rodrigues               9
# 34    8479026        4  20202021   Philippe         Myers               5
# 35    8479193        5  20202021      Casey       DeSmith               1
# 36    8479293        5  20202021    Brandon         Tanev              13
# 37    8479394        4  20202021     Carter          Hart              79
# 38    8479974        4  20202021      Nolan       Patrick              19
# 39    8480797        4  20202021       Joel       Farabee              86
#
#    position_code                                           headshot
# 0              G  https://assets.nhle.com/mugs/nhl/20202021/PHI/...
# 1              C  https://assets.nhle.com/mugs/nhl/20202021/PIT/...
# 2              C  https://assets.nhle.com/mugs/nhl/20202021/PIT/...
# 3              D  https://assets.nhle.com/mugs/nhl/20202021/PIT/...
# 4              R  https://assets.nhle.com/mugs/nhl/20202021/PHI/...
# 5              D  https://assets.nhle.com/mugs/nhl/20202021/PHI/...
# 6              L  https://assets.nhle.com/mugs/nhl/20202021/PHI/...
# 7              C  https://assets.nhle.com/mugs/nhl/20202021/PIT/...
# 8              R  https://assets.nhle.com/mugs/nhl/20202021/PHI/...
# 9              D  https://assets.nhle.com/mugs/nhl/20202021/PIT/...
# 10             L  https://assets.nhle.com/mugs/nhl/20202021/PIT/...
# 11             R  https://assets.nhle.com/mugs/nhl/20202021/PHI/...
# 12             R  https://assets.nhle.com/mugs/nhl/20202021/PIT/...
# 13             C  https://assets.nhle.com/mugs/nhl/20202021/PHI/...
# 14             L  https://assets.nhle.com/mugs/nhl/20202021/PHI/...
# 15             C  https://assets.nhle.com/mugs/nhl/20202021/PIT/...
# 16             D  https://assets.nhle.com/mugs/nhl/20202021/PIT/...
# 17             D  https://assets.nhle.com/mugs/nhl/20202021/PIT/...
# 18             C  https://assets.nhle.com/mugs/nhl/20202021/PIT/...
# 19             D  https://assets.nhle.com/mugs/nhl/20202021/PHI/...
# 20             L  https://assets.nhle.com/mugs/nhl/20202021/PHI/...
# 21             C  https://assets.nhle.com/mugs/nhl/20202021/PIT/...
# 22             D  https://assets.nhle.com/mugs/nhl/20202021/PHI/...
# 23             G  https://assets.nhle.com/mugs/nhl/20202021/PIT/...
# 24             D  https://assets.nhle.com/mugs/nhl/20202021/PHI/...
# 25             C  https://assets.nhle.com/mugs/nhl/20202021/PIT/...
# 26             D  https://assets.nhle.com/mugs/nhl/20202021/PIT/...
# 27             R  https://assets.nhle.com/mugs/nhl/20202021/PHI/...
# 28             C  https://assets.nhle.com/mugs/nhl/20202021/PIT/...
# 29             L  https://assets.nhle.com/mugs/nhl/20202021/PHI/...
# 30             C  https://assets.nhle.com/mugs/nhl/20202021/PHI/...
# 31             D  https://assets.nhle.com/mugs/nhl/20202021/PHI/...
# 32             D  https://assets.nhle.com/mugs/nhl/20202021/PIT/...
# 33             C  https://assets.nhle.com/mugs/nhl/20202021/PIT/...
# 34             D  https://assets.nhle.com/mugs/nhl/20202021/PHI/...
# 35             G  https://assets.nhle.com/mugs/nhl/20202021/PIT/...
# 36             L  https://assets.nhle.com/mugs/nhl/20202021/PIT/...
# 37             G  https://assets.nhle.com/mugs/nhl/20202021/PHI/...
# 38             C  https://assets.nhle.com/mugs/nhl/20202021/PHI/...
# 39             L  https://assets.nhle.com/mugs/nhl/20202021/PHI/...

# %%
bucket_raw = s3.Bucket("frozen-facts-center-raw")
bucket_base = s3.Bucket("frozen-facts-center-base")

for obj_raw in tqdm(bucket_raw.objects.all(), total=len(list(bucket_raw.objects.all()))):
    
    # skip folders
    if not obj_raw.key.endswith(".json"):
        continue
    
    # read data
    raw_game = read_json_from_s3(bucket_name=bucket_raw.name, key=obj_raw.key)
    df = get_df_players(raw_game=raw_game)
    
    # save data into PARQUET file
    parquet_file_key = obj_raw.key.replace("games/", "players/").replace(".json", ".parquet")
    # df.to_parquet(path=f"s3://{bucket_base.name}/{parquet_file_key}", index=False)
    
    file_path = DATA_PATH / parquet_file_key
    file_path.parent.mkdir(parents=True, exist_ok=True)
    df.to_parquet(path=file_path)
    
    # break
# Out:
#   0%|          | 0/4485 [00:00<?, ?it/s]
