# %%
import io
import json
import os
from pathlib import Path

import boto3
import pandas as pd
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", 100)

from tqdm.notebook import tqdm

# %%
S3_ACCESS_KEY_ID = ""
S3_SECRET_ACCESS_KEY = ""

DATA_PATH = Path("/usr/src/app/data/")

# %%
s3 = boto3.resource(
    "s3",
    aws_access_key_id=S3_ACCESS_KEY_ID,
    aws_secret_access_key=S3_SECRET_ACCESS_KEY
)


def read_json_from_s3(bucket_name: str, key: str) -> pd.DataFrame:
    return json.loads(
        s3.Object(bucket_name=bucket_name, key=key)
        .get()["Body"]
        .read()
        .decode("utf-8")
    )


def read_parquet_from_s3(bucket_name: str, key: str) -> pd.DataFrame:
    return pd.read_parquet(
        io.BytesIO(
            s3.Object(bucket_name=bucket_name, key=key)
            .get()["Body"]
            .read()
        )
    )

def get_general_game_features(game: dict) -> dict:
    return {
        "game_id": game.get("id"),
        "game_date": game.get("gameDate"),
        "away_team_id": game.get("awayTeam", {}).get("id"),
        "home_team_id": game.get("homeTeam", {}).get("id"),
    }

def get_df_players(game: dict) -> pd.DataFrame:
    return pd.DataFrame(
        [
            {
                **get_general_game_features(game=game),
                "player_id": player.get("playerId"),
                "team_id": player.get("teamId"),
                "season": game.get("season"),
                "first_name": player.get("firstName").get("default"),
                "last_name": player.get("lastName").get("default"),
                "sweater_number": player.get("sweaterNumber"),
                "position_code": player.get("positionCode"),
                "headshot": player.get("headshot"),
            } 
            for player in game.get("rosterSpots")
        ]
    )

# %%
BUCKET_NAME = "frozen-facts-center-raw"
KEY = "games/2020/regular/2020020003.json"

game = read_json_from_s3(bucket_name=BUCKET_NAME, key=KEY)
df_players = get_df_players(game=game)

df_players
# Out:
#        game_id   game_date  away_team_id  home_team_id  player_id  team_id  \
# 0   2020020003  2021-01-13             8            10    8466138       10
# 1   2020020003  2021-01-13             8            10    8469455       10
# 2   2020020003  2021-01-13             8            10    8470642        8
# 3   2020020003  2021-01-13             8            10    8471679        8
# 4   2020020003  2021-01-13             8            10    8473507        8
# 5   2020020003  2021-01-13             8            10    8474038        8
# 6   2020020003  2021-01-13             8            10    8474162       10
# 7   2020020003  2021-01-13             8            10    8474190       10
# 8   2020020003  2021-01-13             8            10    8474567       10
# 9   2020020003  2021-01-13             8            10    8474596        8
# 10  2020020003  2021-01-13             8            10    8474673       10
# 11  2020020003  2021-01-13             8            10    8475166       10
# 12  2020020003  2021-01-13             8            10    8475193        8
# 13  2020020003  2021-01-13             8            10    8475279        8
# 14  2020020003  2021-01-13             8            10    8475718       10
# 15  2020020003  2021-01-13             8            10    8475726        8
# 16  2020020003  2021-01-13             8            10    8475786       10
# 17  2020020003  2021-01-13             8            10    8475789       10
# 18  2020020003  2021-01-13             8            10    8475848        8
# 19  2020020003  2021-01-13             8            10    8475883       10
# 20  2020020003  2021-01-13             8            10    8476441        8
# 21  2020020003  2021-01-13             8            10    8476469        8
# 22  2020020003  2021-01-13             8            10    8476479        8
# 23  2020020003  2021-01-13             8            10    8476853       10
# 24  2020020003  2021-01-13             8            10    8476918       10
# 25  2020020003  2021-01-13             8            10    8476967        8
# 26  2020020003  2021-01-13             8            10    8476981        8
# 27  2020020003  2021-01-13             8            10    8477021       10
# 28  2020020003  2021-01-13             8            10    8477476        8
# 29  2020020003  2021-01-13             8            10    8477494        8
# 30  2020020003  2021-01-13             8            10    8477939       10
# 31  2020020003  2021-01-13             8            10    8478133        8
# 32  2020020003  2021-01-13             8            10    8478408       10
# 33  2020020003  2021-01-13             8            10    8478483       10
# 34  2020020003  2021-01-13             8            10    8479318       10
# 35  2020020003  2021-01-13             8            10    8480018        8
# 36  2020020003  2021-01-13             8            10    8480829        8
# 37  2020020003  2021-01-13             8            10    8481014        8
# 38  2020020003  2021-01-13             8            10    8481624       10
# 39  2020020003  2021-01-13             8            10    8482222       10
#
#       season first_name   last_name  sweater_number position_code  \
# 0   20202021        Joe    Thornton              97             C
# 1   20202021      Jason      Spezza              19             C
# 2   20202021       Shea       Weber               6             D
# 3   20202021      Carey       Price              31             G
# 4   20202021       Jeff       Petry              26             D
# 5   20202021       Paul       Byron              41             L
# 6   20202021       Jake      Muzzin               8             D
# 7   20202021      Wayne    Simmonds              24             R
# 8   20202021       Zach    Bogosian              22             D
# 9   20202021       Jake       Allen              34             G
# 10  20202021         TJ      Brodie              78             D
# 11  20202021       John     Tavares              91             C
# 12  20202021      Tomas       Tatar              90             L
# 13  20202021        Ben     Chiarot               8             D
# 14  20202021     Justin        Holl               3             D
# 15  20202021      Tyler     Toffoli              73             C
# 16  20202021       Zach       Hyman              11             C
# 17  20202021       Jack    Campbell              36             G
# 18  20202021    Brendan   Gallagher              11             R
# 19  20202021   Frederik    Andersen              31             G
# 20  20202021       Joel   Edmundson              44             D
# 21  20202021       Joel       Armia              40             R
# 22  20202021    Phillip     Danault              24             L
# 23  20202021     Morgan      Rielly              44             D
# 24  20202021      Jimmy       Vesey              26             L
# 25  20202021      Brett       Kulak              77             D
# 26  20202021       Josh    Anderson              17             R
# 27  20202021       Alex     Kerfoot              15             C
# 28  20202021    Artturi    Lehkonen              62             L
# 29  20202021   Jonathan      Drouin              92             L
# 30  20202021    William    Nylander              88             C
# 31  20202021       Jake       Evans              71             C
# 32  20202021     Travis     Dermott              23             D
# 33  20202021   Mitchell      Marner              16             C
# 34  20202021     Auston    Matthews              34             C
# 35  20202021       Nick      Suzuki              14             C
# 36  20202021    Jesperi  Kotkaniemi              15             C
# 37  20202021  Alexander     Romanov              27             D
# 38  20202021       Ilya    Mikheyev              65             R
# 39  20202021  Alexander   Barabanov              94             L
#
#                                              headshot
# 0   https://assets.nhle.com/mugs/nhl/20202021/TOR/...
# 1   https://assets.nhle.com/mugs/nhl/20202021/TOR/...
# 2   https://assets.nhle.com/mugs/nhl/20202021/MTL/...
# 3   https://assets.nhle.com/mugs/nhl/20202021/MTL/...
# 4   https://assets.nhle.com/mugs/nhl/20202021/MTL/...
# 5   https://assets.nhle.com/mugs/nhl/20202021/MTL/...
# 6   https://assets.nhle.com/mugs/nhl/20202021/TOR/...
# 7   https://assets.nhle.com/mugs/nhl/20202021/TOR/...
# 8   https://assets.nhle.com/mugs/nhl/20202021/TOR/...
# 9   https://assets.nhle.com/mugs/nhl/20202021/MTL/...
# 10  https://assets.nhle.com/mugs/nhl/20202021/TOR/...
# 11  https://assets.nhle.com/mugs/nhl/20202021/TOR/...
# 12  https://assets.nhle.com/mugs/nhl/20202021/MTL/...
# 13  https://assets.nhle.com/mugs/nhl/20202021/MTL/...
# 14  https://assets.nhle.com/mugs/nhl/20202021/TOR/...
# 15  https://assets.nhle.com/mugs/nhl/20202021/MTL/...
# 16  https://assets.nhle.com/mugs/nhl/20202021/TOR/...
# 17  https://assets.nhle.com/mugs/nhl/20202021/TOR/...
# 18  https://assets.nhle.com/mugs/nhl/20202021/MTL/...
# 19  https://assets.nhle.com/mugs/nhl/20202021/TOR/...
# 20  https://assets.nhle.com/mugs/nhl/20202021/MTL/...
# 21  https://assets.nhle.com/mugs/nhl/20202021/MTL/...
# 22  https://assets.nhle.com/mugs/nhl/20202021/MTL/...
# 23  https://assets.nhle.com/mugs/nhl/20202021/TOR/...
# 24  https://assets.nhle.com/mugs/nhl/20202021/TOR/...
# 25  https://assets.nhle.com/mugs/nhl/20202021/MTL/...
# 26  https://assets.nhle.com/mugs/nhl/20202021/MTL/...
# 27  https://assets.nhle.com/mugs/nhl/20202021/TOR/...
# 28  https://assets.nhle.com/mugs/nhl/20202021/MTL/...
# 29  https://assets.nhle.com/mugs/nhl/20202021/MTL/...
# 30  https://assets.nhle.com/mugs/nhl/20202021/TOR/...
# 31  https://assets.nhle.com/mugs/nhl/20202021/MTL/...
# 32  https://assets.nhle.com/mugs/nhl/20202021/TOR/...
# 33  https://assets.nhle.com/mugs/nhl/20202021/TOR/...
# 34  https://assets.nhle.com/mugs/nhl/20202021/TOR/...
# 35  https://assets.nhle.com/mugs/nhl/20202021/MTL/...
# 36  https://assets.nhle.com/mugs/nhl/20202021/MTL/...
# 37  https://assets.nhle.com/mugs/nhl/20202021/MTL/...
# 38  https://assets.nhle.com/mugs/nhl/20202021/TOR/...
# 39  https://assets.nhle.com/mugs/nhl/20202021/TOR/...

# %%
bucket_raw = s3.Bucket("frozen-facts-center-raw")
bucket_base = s3.Bucket("frozen-facts-center-base")

for obj_raw in tqdm(bucket_raw.objects.all(), total=len(list(bucket_raw.objects.all()))):
    
    # skip folders
    if not obj_raw.key.endswith(".json"):
        continue
    
    # read data
    game = read_json_from_s3(bucket_name=bucket_raw.name, key=obj_raw.key)
    df = get_df_players(game=game)
    
    # save data into PARQUET file
    parquet_file_key = obj_raw.key.replace("games/", "players/").replace(".json", ".parquet")
    # df.to_parquet(path=f"s3://{bucket_base.name}/{parquet_file_key}", index=False)
    
    file_path = DATA_PATH / parquet_file_key
    file_path.parent.mkdir(parents=True, exist_ok=True)
    df.to_parquet(path=file_path)
    
    # break
# Out:
#   0%|          | 0/5153 [00:00<?, ?it/s]
